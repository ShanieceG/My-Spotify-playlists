# %% [markdown]
# # Purpose
# Music is a big part of my life. I listen to music everyday during work, doing chores already the house, pretty much whenever I can. I use Spotify because I like that I can create my own playlists of my favorite songs and artists. There have been a couple of times where I lost my playlists due to changing accounts, so I like to have a back up of my playlists. As one can imagine this can be quite a tedious task when I've been adding and curating multiple playlists for over 5 years. Thus I created this notebook to help me clean and alter the playlist data that I've downloaded from Spotify.

# %%
# Load necessary packages
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
#Open and read json file with Spotify Playlists
import json
with open ('/kaggle/input/spotify-playlists/Playlist1.json', 'r') as openfile:
    json.object = json.load(openfile)
#print(json.object)

# %%
#Convert and normalize data from JSON file into dataframe
#Split nested dictionaries in JSON file to get track info, and keep name and lastModifiedDate columns
df=pd.json_normalize(json.object['playlists'], "items", ["name", "lastModifiedDate"])

# %% [markdown]
# ### JSON and Nested Dictionaries
# This was my first time working with a JSON file. It took me a while to figure out how to flatten the data into a dataframe. At first I was able to get a dataframe with the items column containing all the information that I wanted. I tried splitting the strings. Then I tried to change the data types thinking it would make the string split work, but that also failed. Once I realized that the data was arranged in nested dictionaries I found a solution on the site pandas.pydata.org that allowed me to flatten everything all at once, giving me the dataframe that I wanted. After that I was able to clean up the data and column names.

# %%
#Drop unwanted columns
uw_columns = ['episode', 'audiobook', 'localTrack','localTrack.uri','track.trackUri', 'track']
df.drop(uw_columns, axis=1, inplace=True)

# %%
#Change column names to remove track prefix and specify column of playlist names
df.rename(columns={"track.trackName":"trackName", "track.artistName":"artistName", "track.albumName":"album","name":"playlistName"}, inplace=True)

#Noticed spelt name of artist wrong when inputting playist title; replacing name with correct spelling
df['playlistName'].replace({'Durand Bernard': 'Durand Bernarr'}, inplace=True)
df
# Out:
# <ipython-input-5-7b6a9a52a844>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['playlistName'].replace({'Durand Bernard': 'Durand Bernarr'}, inplace=True)
#        addedDate    trackName      artistName       album    playlistName  \
# 0     2025-01-20   Boundaries  Durand Bernarr  Wanderlust  Durand Bernarr
# 1     2025-01-20   Footprints  Durand Bernarr  Wanderlust  Durand Bernarr
# 2     2025-01-20      Lil Bit  Durand Bernarr  Wanderlust  Durand Bernarr
# 3     2025-01-20      Leveled  Durand Bernarr  Wanderlust  Durand Bernarr
# 4     2025-01-20  Ingredients  Durand Bernarr  Wanderlust  Durand Bernarr
# ...          ...          ...             ...         ...             ...
# 2448  2013-09-30          NaN             NaN         NaN            Wale
# 2449  2013-09-30          NaN             NaN         NaN            Wale
# 2450  2013-09-30          NaN             NaN         NaN            Wale
# 2451  2013-09-30          NaN             NaN         NaN            Wale
# 2452  2013-09-30          NaN             NaN         NaN            Wale
#
#      lastModifiedDate
# 0          2025-01-21
# 1          2025-01-21
# 2          2025-01-21
# 3          2025-01-21
# 4          2025-01-21
# ...               ...
# 2448       2018-09-04
# 2449       2018-09-04
# 2450       2018-09-04
# 2451       2018-09-04
# 2452       2018-09-04
#
# [2453 rows x 6 columns]

# %% [markdown]
# ### iTunes Playlist
# When I first started using Spotify I had a Mac. You can play you iTunes playlist through Spotify, but I didn't do that very often as I could just play the music through iTunes. I've never played attention to the playlist in Spotify but it could still show up in the data I downloaded. So I wanted to remove any of these playlists/songs from the data because it's not something that I will ever change or update.

# %%
#List all unique playlists to see if need to remove iTunes from list
pd.unique(df['playlistName'])
# Out:
# array(['Durand Bernarr', 'SiR', 'Terrell Grice', 'Raye', 'Glorilla',
#        'Tyler the Creator', 'Doechii', 'Childish Gambino', 'ScHoolboy Q',
#        'Jungle', 'Armani White', 'Janelle Monae', 'grouptherapy.',
#        'Paramore', 'I DON’T KNOW HOW BUT THEY FOUND ME',
#        'Charlie Curtis-Beard', 'Jean Deux', 'Bree Runway',
#        'Jacob Collier', 'The Arcs', 'Kendrick Lamar', 'Yeah it’s Ak',
#        'Joyce Wrice', 'Teo', 'Tierra Whack', 'Nao', 'Mary J Blige',
#        'Lucky Daye', 'Wale', 'Adele', 'Smino', 'Kali Uchis',
#        'X Ambassadors', 'Little Simz', 'Piff Marti', 'Amber Mark',
#        'Labrinth', 'Jazmine Sullivan', 'John Legend',
#        'Megan Thee Stallion', 'Victoria Monet', 'Duckwrth',
#        'Teyana Taylor', 'Chloe x Halle', 'KAYTRANADA', 'Mahalia', 'Keats',
#        'Chance The Rapper', 'Missy', 'Beyonce', 'Tobe Nwigwe',
#        'Leikeli47', 'Lizzo', 'LSD', 'DRAM', 'Billie Eilish', 'Jorja',
#        'The Internet', 'Tinashe', 'Anderson.Paak', 'The Heavy',
#        'Panic! At the Disco', 'Ariana Grande', 'Fitz & the Tantrums',
#        'Pharrell Williams', 'Sia', 'Johnnyswim', 'Trilogy', 'Favorites',
#        'Janet Jackson', 'Masego', 'Doja Cat', 'Drake', 'GoldLink',
#        'Toni Braxton', 'Khalid', 'Daniel Merriweather', 'Listen Up!',
#        'OneRepublic'], dtype=object)

# %%
#Drop OneRepublic playlist
One_Rep= df[df['playlistName']=='OneRepublic']
df.drop(One_Rep.index, axis=0, inplace=True)
pd.unique(df['playlistName'])
# Out:
# array(['Durand Bernarr', 'SiR', 'Terrell Grice', 'Raye', 'Glorilla',
#        'Tyler the Creator', 'Doechii', 'Childish Gambino', 'ScHoolboy Q',
#        'Jungle', 'Armani White', 'Janelle Monae', 'grouptherapy.',
#        'Paramore', 'I DON’T KNOW HOW BUT THEY FOUND ME',
#        'Charlie Curtis-Beard', 'Jean Deux', 'Bree Runway',
#        'Jacob Collier', 'The Arcs', 'Kendrick Lamar', 'Yeah it’s Ak',
#        'Joyce Wrice', 'Teo', 'Tierra Whack', 'Nao', 'Mary J Blige',
#        'Lucky Daye', 'Wale', 'Adele', 'Smino', 'Kali Uchis',
#        'X Ambassadors', 'Little Simz', 'Piff Marti', 'Amber Mark',
#        'Labrinth', 'Jazmine Sullivan', 'John Legend',
#        'Megan Thee Stallion', 'Victoria Monet', 'Duckwrth',
#        'Teyana Taylor', 'Chloe x Halle', 'KAYTRANADA', 'Mahalia', 'Keats',
#        'Chance The Rapper', 'Missy', 'Beyonce', 'Tobe Nwigwe',
#        'Leikeli47', 'Lizzo', 'LSD', 'DRAM', 'Billie Eilish', 'Jorja',
#        'The Internet', 'Tinashe', 'Anderson.Paak', 'The Heavy',
#        'Panic! At the Disco', 'Ariana Grande', 'Fitz & the Tantrums',
#        'Pharrell Williams', 'Sia', 'Johnnyswim', 'Trilogy', 'Favorites',
#        'Janet Jackson', 'Masego', 'Doja Cat', 'Drake', 'GoldLink',
#        'Toni Braxton', 'Khalid', 'Daniel Merriweather', 'Listen Up!'],
#       dtype=object)

# %%
#Check Wale playlist to make sure doesn't include iTunes songs
Wale_df=df[df['playlistName']=='Wale']
Wale_df
# Out:
#        addedDate                                          trackName  \
# 580   2022-01-10                        Poke It Out (feat. J. Cole)
# 581   2022-01-10                                       New Balances
# 582   2022-01-10              Routine (feat. Rick Ross & Meek Mill)
# 583   2022-01-10                           On Chill (feat. Jeremih)
# 584   2022-01-10                         Sue Me (feat. Kelly Price)
# 585   2022-01-10                        Fashion Week (feat. G-Eazy)
# 586   2022-01-10                                      Tiffany Nikes
# 587   2022-01-10  More Love (feat. Shawn Stockman of Boyz ll Men...
# 588   2022-01-10        Down South (feat. Yella Beezy & Maxo Kream)
# 589   2022-01-10                                     BYGPW (Colors)
# 590   2023-01-27                             So Lonely (feat. Wale)
# 2437  2013-09-30                                                NaN
# 2438  2013-09-30                                                NaN
# 2439  2013-09-30                                                NaN
# 2440  2013-09-30                                                NaN
# 2441  2013-09-30                                                NaN
# 2442  2013-09-30                                                NaN
# 2443  2013-09-30                                                NaN
# 2444  2013-09-30                                                NaN
# 2445  2013-09-30                                                NaN
# 2446  2013-09-30                                                NaN
# 2447  2013-09-30                                                NaN
# 2448  2013-09-30                                                NaN
# 2449  2013-09-30                                                NaN
# 2450  2013-09-30                                                NaN
# 2451  2013-09-30                                                NaN
# 2452  2013-09-30                                                NaN
#
#      artistName                album playlistName lastModifiedDate
# 580        Wale           Folarin II         Wale       2023-01-27
# 581        Wale           Folarin II         Wale       2023-01-27
# 582        Wale  Wow... That's Crazy         Wale       2023-01-27
# 583        Wale  Wow... That's Crazy         Wale       2023-01-27
# 584        Wale  Wow... That's Crazy         Wale       2023-01-27
# 585        Wale                Shine         Wale       2023-01-27
# 586        Wale           Folarin II         Wale       2023-01-27
# 587        Wale           Folarin II         Wale       2023-01-27
# 588        Wale           Folarin II         Wale       2023-01-27
# 589        Wale  The Imperfect Storm         Wale       2023-01-27
# 590   PJ Morton        Watch The Sun         Wale       2023-01-27
# 2437        NaN                  NaN         Wale       2018-09-04
# 2438        NaN                  NaN         Wale       2018-09-04
# 2439        NaN                  NaN         Wale       2018-09-04
# 2440        NaN                  NaN         Wale       2018-09-04
# 2441        NaN                  NaN         Wale       2018-09-04
# 2442        NaN                  NaN         Wale       2018-09-04
# 2443        NaN                  NaN         Wale       2018-09-04
# 2444        NaN                  NaN         Wale       2018-09-04
# 2445        NaN                  NaN         Wale       2018-09-04
# 2446        NaN                  NaN         Wale       2018-09-04
# 2447        NaN                  NaN         Wale       2018-09-04
# 2448        NaN                  NaN         Wale       2018-09-04
# 2449        NaN                  NaN         Wale       2018-09-04
# 2450        NaN                  NaN         Wale       2018-09-04
# 2451        NaN                  NaN         Wale       2018-09-04
# 2452        NaN                  NaN         Wale       2018-09-04

# %%
#Drop Wale songs using index range
df.drop(index=range(2437,2453), axis=0, inplace=True)
df
# Out:
#        addedDate               trackName      artistName       album  \
# 0     2025-01-20              Boundaries  Durand Bernarr  Wanderlust
# 1     2025-01-20              Footprints  Durand Bernarr  Wanderlust
# 2     2025-01-20                 Lil Bit  Durand Bernarr  Wanderlust
# 3     2025-01-20                 Leveled  Durand Bernarr  Wanderlust
# 4     2025-01-20             Ingredients  Durand Bernarr  Wanderlust
# ...          ...                     ...             ...         ...
# 2421  2013-10-02              Wonderland  Haley Reinhart  Listen Up!
# 2422  2013-10-02        Keep Coming Back  Haley Reinhart  Listen Up!
# 2423  2013-10-02  Hit The Ground Runnin'  Haley Reinhart  Listen Up!
# 2424  2013-10-02       Walking On Heaven  Haley Reinhart  Listen Up!
# 2425  2022-03-03           Talkin' About  Haley Reinhart      Better
#
#         playlistName lastModifiedDate
# 0     Durand Bernarr       2025-01-21
# 1     Durand Bernarr       2025-01-21
# 2     Durand Bernarr       2025-01-21
# 3     Durand Bernarr       2025-01-21
# 4     Durand Bernarr       2025-01-21
# ...              ...              ...
# 2421      Listen Up!       2022-03-03
# 2422      Listen Up!       2022-03-03
# 2423      Listen Up!       2022-03-03
# 2424      Listen Up!       2022-03-03
# 2425      Listen Up!       2022-03-03
#
# [2426 rows x 6 columns]

# %% [markdown]
# ### Making New Playlists
# Whenever I have 5 or more songs by an artist or that artist is on in my Favorites playlist, I like to create a separate playlist of just that artist. I do this because get allows me to hear more suggested songs from my favorite artists when I just listen to their music. I want to go through my Favorites playlist and find any artists that I have 5 or more songs in the playlist.

# %%
# Find artists with 5 or more songs in Favorites playlist
Fav_play = df[df['playlistName']=='Favorites']
Fav_play5=Fav_play.groupby(['artistName'])[['trackName']].nunique()
Fav_play5=Fav_play5.loc[Fav_play5['trackName']>=5]
Fav_play5
# Out:
#                      trackName
# artistName
# J. Cole                      5
# LION BABE                    5
# My Chemical Romance          5
# Princess Nokia               5
# Tove Lo                      5
# Xavier Omär                  5

# %%
#Find indexes of all songs and change playlist name from Favorites to artist name. Some artists had more songs that included other artists; will move those songs to same playlist separately
Fav_play5_artists = ['J. Cole', 'LION BABE', 'My Chemical Romance', 'Princess Nokia', 'Tove Lo']
Fav_play5_ind=df[df['artistName'].isin(Fav_play5_artists)].index
df.loc[Fav_play5_ind]
# Out:
#        addedDate                                         trackName  \
# 1611  2013-12-17                                            Helena
# 1612  2013-12-17                          I'm Not Okay (I Promise)
# 1613  2013-12-17                                  The Ghost of You
# 1714  2014-11-23           She Knows (feat. Amber Coffman & Cults)
# 1715  2014-11-23                                  Can't Get Enough
# 1740  2016-06-09                                      Talking Body
# 1746  2016-07-01                                    No Role Modelz
# 1784  2018-02-14                         Power Trip (feat. Miguel)
# 1797  2018-06-06                      Impossible - Jax Jones Remix
# 1799  2018-07-30                          Rockets (feat. Moe Moks)
# 1821  2018-12-17                            shedontknowbutsheknows
# 1838  2019-02-21                                   Rockets (Remix)
# 1858  2019-05-22                                          The Wave
# 1876  2019-10-18                   Sugar Honey Iced Tea (S.H.I.T.)
# 1948  2020-09-14                                        disco tits
# 1960  2020-10-24                                        I Like Him
# 1961  2020-10-24                                              Wavy
# 2069  2022-01-18                                 It's Not My Fault
# 2076  2022-02-15  How Long - From"Euphoria" An HBO Original Series
# 2087  2022-03-08                                        Impossible
# 2116  2022-04-06                                         No Effort
# 2155  2022-08-29             Are U gonna tell her? (feat. MC Zaac)
# 2179  2022-11-04   You Know What They Do to Guys Like Us in Prison
# 2199  2023-01-09                                   House of Wolves
# 2241  2023-08-14                                               KOD
#
#                artistName                            album playlistName  \
# 1611  My Chemical Romance   Three Cheers for Sweet Revenge    Favorites
# 1612  My Chemical Romance   Three Cheers for Sweet Revenge    Favorites
# 1613  My Chemical Romance   Three Cheers for Sweet Revenge    Favorites
# 1714              J. Cole                      Born Sinner    Favorites
# 1715              J. Cole   Cole World: The Sideline Story    Favorites
# 1740              Tove Lo              Queen Of The Clouds    Favorites
# 1746              J. Cole          2014 Forest Hills Drive    Favorites
# 1784              J. Cole        Power Trip (feat. Miguel)    Favorites
# 1797            LION BABE                       Impossible    Favorites
# 1799            LION BABE         Rockets (feat. Moe Moks)    Favorites
# 1821              Tove Lo                        BLUE LIPS    Favorites
# 1838            LION BABE                  Rockets (Remix)    Favorites
# 1858            LION BABE                      Cosmic Wind    Favorites
# 1876       Princess Nokia  Sugar Honey Iced Tea (S.H.I.T.)    Favorites
# 1948              Tove Lo                        BLUE LIPS    Favorites
# 1960       Princess Nokia                 Everything Sucks    Favorites
# 1961       Princess Nokia          Everything is Beautiful    Favorites
# 2069       Princess Nokia                It's Not My Fault    Favorites
# 2076              Tove Lo                         How Long    Favorites
# 2087            LION BABE                            Begin    Favorites
# 2116       Princess Nokia                        No Effort    Favorites
# 2155              Tove Lo                   Sunshine Kitty    Favorites
# 2179  My Chemical Romance   Three Cheers for Sweet Revenge    Favorites
# 2199  My Chemical Romance                 The Black Parade    Favorites
# 2241              J. Cole                              KOD    Favorites
#
#      lastModifiedDate
# 1611       2025-02-20
# 1612       2025-02-20
# 1613       2025-02-20
# 1714       2025-02-20
# 1715       2025-02-20
# 1740       2025-02-20
# 1746       2025-02-20
# 1784       2025-02-20
# 1797       2025-02-20
# 1799       2025-02-20
# 1821       2025-02-20
# 1838       2025-02-20
# 1858       2025-02-20
# 1876       2025-02-20
# 1948       2025-02-20
# 1960       2025-02-20
# 1961       2025-02-20
# 2069       2025-02-20
# 2076       2025-02-20
# 2087       2025-02-20
# 2116       2025-02-20
# 2155       2025-02-20
# 2179       2025-02-20
# 2199       2025-02-20
# 2241       2025-02-20

# %%
#Because Xavier Omar has special character just searched for songs after finding in Spotify as well as additional songs for J.Cole
Xavier_J_songs = ['Blind Man', 'Just Get Here (feat. Wale & VanJess)', 'FIND ME.', 'want/need', 'Thief', 'Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)', 'Tribe (with J. Cole)']
Xavier_J_ind=df[df['trackName'].isin(Xavier_J_songs)].index
df.loc[Xavier_J_ind]
# Out:
#        addedDate                                          trackName  \
# 1855  2019-04-29                                          Blind Man
# 1957  2020-10-07                               Tribe (with J. Cole)
# 2047  2021-10-29  Down Bad (feat. JID, Bas, J. Cole, EARTHGANG &...
# 2095  2022-03-30               Just Get Here (feat. Wale & VanJess)
# 2118  2022-04-11                                           FIND ME.
# 2221  2023-05-03                                          want/need
# 2279  2024-12-31                                              Thief
#
#        artistName                        album playlistName lastModifiedDate
# 1855  Xavier Omär                    Blind Man    Favorites       2025-02-20
# 1957          Bas                    Milky Way    Favorites       2025-02-20
# 2047   Dreamville  Revenge Of The Dreamers III    Favorites       2025-02-20
# 2095  Xavier Omär     Moments Spent Loving You    Favorites       2025-02-20
# 2118  Xavier Omär                  if You Feel    Favorites       2025-02-20
# 2221  Xavier Omär                  if You Feel    Favorites       2025-02-20
# 2279  Xavier Omär     Moments Spent Loving You    Favorites       2025-02-20

# %%
#Because other song with Princess Nokia had such long name and multiple artists used album name instead to get index
LMK = ['TAKE ME A_PART, THE REMIXES']
lmk_ind=df[df['album'].isin(LMK)].index
df.loc[lmk_ind]
# Out:
#        addedDate                                          trackName  \
# 975   2021-02-25                          KAYTRANADA_WAITIN_115 BPM
# 1929  2020-06-26  LMK_WHAT’S REALLY GOOD REMIX_ FEAT_PRINCESS NO...
#
#      artistName                        album playlistName lastModifiedDate
# 975      Kelela  TAKE ME A_PART, THE REMIXES   KAYTRANADA       2024-10-31
# 1929     Kelela  TAKE ME A_PART, THE REMIXES    Favorites       2025-02-20

# %%
#Change playlist names for songs moved to new playlists, and change artist name for Xavier Omar for ease
MCR_ind = [1611, 1612 ,1613, 2179, 2199]
JC_ind = [1714, 1715, 1746, 1784, 1957, 2047, 2241]
Tove_ind = [1740, 1821, 1948, 2076, 2155]
Lion_ind = [1797, 1799, 1838, 1858, 2087]
PN_ind = [1876, 1929, 1960, 1961, 2069, 2116]
XO_ind = [1855, 2095, 2118, 2221, 2279]
df.loc[MCR_ind, 'playlistName'] = 'My Chemical Romance'
df.loc[JC_ind, 'playlistName'] = 'J. Cole'
df.loc[Tove_ind, 'playlistName'] = 'Tove Lo'
df.loc[Lion_ind, 'playlistName'] = 'LION BABE'
df.loc[PN_ind, 'playlistName'] = 'Princess Nokia'
df.loc[XO_ind, 'playlistName'] = 'Xavier Omar'
df.loc[XO_ind, 'artistName'] = 'Xavier Omar'

# %%
#Single songs moved to existing playlists
Sir_songs = ["Fuck Y'all (feat.SiR)"]
Sir_ind = df[df['trackName'].isin(Sir_songs)].index
df.loc[Sir_ind, 'playlistName'] = 'SiR'

Doechii_songs = ['What It Is (Solo Version)']
Doechii_ind = df[df['trackName'].isin(Doechii_songs)].index
df.loc[Doechii_ind, 'playlistName'] = 'Doechii'

JM_songs = ['Do My Thing']
JM_ind = df[df['trackName'].isin(JM_songs)].index
df.loc[JM_ind, 'playlistName'] = 'Janelle Monae'

KL_songs = ['Wow Freestyle (feat. Kendrick Lamar']
KL_ind = df[df['trackName'].isin(KL_songs)].index
df.loc[KL_ind, 'playlistName'] = 'Kendrick Lamar'

JL_songs = ['Tonight (Best You Ever Had)(feat. Ludacris)', 'Selfish']
JL_ind = df[df['trackName'].isin(JL_songs)].index
df.loc[JL_ind, 'playlistName'] = 'John Legend'

CTR_songs = ['Girls @ (feat. Chance the Rapper)']
CTR_ind = df[df['trackName'].isin(CTR_songs)].index
df.loc[CTR_ind, 'playlistName'] = 'Chance the Rapper'

Missy_songs = ['Strive', 'Can We (feat. Missy "Misdemeanor" Elliott)']
Missy_ind = df[df['trackName'].isin(Missy_songs)].index
df.loc[Missy_ind, 'playlistName'] = 'Missy'

Lizzo_songs = ['Karaoke (feat. Lizzo)']
Lizzo_ind = df[df['trackName'].isin(Lizzo_songs)].index
df.loc[Lizzo_ind, 'playlistName'] = 'Lizzo'

Jorja_songs = ['Peng Black Girls Remix - A COLORS SHOW']
Jorja_ind = df[df['trackName'].isin(Jorja_songs)].index
df.loc[Jorja_ind, 'playlistName'] = 'Jorja'

Tinashe_songs = ['Drop That Kitty (feat. Charli XCX & Tinashe)']
Tinashe_ind = df[df['trackName'].isin(Tinashe_songs)].index
df.loc[Tinashe_ind, 'playlistName'] = 'Tinashe'

PW_songs = ['Lose Yourself to Dance (feat. Pharrell Williams)', 'Finna Get Loose']
PW_ind = df[df['trackName'].isin(PW_songs)].index
df.loc[PW_ind, 'playlistName'] = 'Pharrell Williams'

Drake_songs = ['Pop That', 'Live For']
Drake_ind = df[df['trackName'].isin(Drake_songs)].index
df.loc[Drake_ind, 'playlistName'] = 'Drake'

# %%
#Artists that had enough songs to create their own playlist
Syd_songs = ['Do U Wrong (feat. Syd)', 'MADE 4 U', 'Take Care of You (feat. Syd)', 'Dollar Bills (feat. Steve Lacy)', 'Shibuya (feat. Syd)']
Syd_ind = df[df['trackName'].isin(Syd_songs)].index
df.loc[Syd_ind, 'playlistName'] = 'Syd'

NM_songs = ['Monster', 'Anaconda', 'Truffle Butter', 'Rake It Up', 'Anybody (feat. Nicki Minaj)', 'Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj']
NM_ind = df[df['trackName'].isin(NM_songs)].index
df.loc[NM_ind, 'playlistName'] = 'Nicki Minaj'

# %% [markdown]
# ### New Songs
# Since this data was downloaded I have added new songs to some playlists. There are 4 playlists that I recently added songs to that may not be in this dataset. Those playlists are: Favorites, Durand Bernarr, SiR, and Tyler the Creator. I created a subset for each of these playlists and found the most recent song added, if there are songs in the playlisst that are after the most recent song then I added those songs into the dataset. I did this by creating a separate dataframe of the new songs and combining it with the cleaned dataframe to get the final result.

# %%
#Show most recent song that was added to Favorites playlist
Fav_play.loc[df['addedDate'].idxmax()]
# Out:
# addedDate             2025-02-20
# trackName                    WHY
# artistName          Sasha Keable
# album                        WHY
# playlistName           Favorites
# lastModifiedDate      2025-02-20
# Name: 2285, dtype: object

# %% [markdown]
# While trying to find the most recent songs in the other playlists the above code wouldn't work so I had to find the most recent songs another way.

# %%
#Show most recent song added to SiR playlist
Sir_play = df[df['playlistName']=='SiR']
Sir_play.sort_values(by='addedDate',ascending=False)
# Out:
#      addedDate                          trackName artistName           album  \
# 60  2025-02-07                   Wires in the Way        SiR  Chasing Summer
# 70  2025-02-07                            NO EVIL        SiR           HEAVY
# 76  2025-02-07  LIFE IS GOOD (feat. Scribz Riley)        SiR           HEAVY
# 75  2025-02-07                       SATISFACTION        SiR           HEAVY
# 74  2025-02-07                         ONLY HUMAN        SiR           HEAVY
# ..         ...                                ...        ...             ...
# 36  2025-01-03                 The Perfect Remedy        SiR   Seven Sundays
# 37  2025-01-03                      Crashing Down        SiR   Seven Sundays
# 38  2025-01-03             The Bullet and the Gun        SiR   Seven Sundays
# 39  2025-01-03              He Deserves Your Love        SiR   Seven Sundays
# 26  2025-01-03                           Love You        SiR   Seven Sundays
#
#    playlistName lastModifiedDate
# 60          SiR       2025-02-07
# 70          SiR       2025-02-07
# 76          SiR       2025-02-07
# 75          SiR       2025-02-07
# 74          SiR       2025-02-07
# ..          ...              ...
# 36          SiR       2025-02-07
# 37          SiR       2025-02-07
# 38          SiR       2025-02-07
# 39          SiR       2025-02-07
# 26          SiR       2025-02-07
#
# [69 rows x 6 columns]

# %%
#Show most recent song added to Durand Bernarr playlist
DB_play = df[df['playlistName']=='Durand Bernarr']
DB_play.sort_values(by='addedDate', ascending=False)
# Out:
#      addedDate       trackName      artistName       album    playlistName  \
# 13  2025-01-21          Melody  Durand Bernarr        DUR&  Durand Bernarr
# 14  2025-01-21          STUCK.  Durand Bernarr        DUR&  Durand Bernarr
# 24  2025-01-21         Summons  Durand Bernarr        DUR&  Durand Bernarr
# 23  2025-01-21        Passport  Durand Bernarr        DUR&  Durand Bernarr
# 22  2025-01-21         RACKET!  Durand Bernarr        DUR&  Durand Bernarr
# 21  2025-01-21          Volume  Durand Bernarr        DUR&  Durand Bernarr
# 20  2025-01-21        Prepared  Durand Bernarr        DUR&  Durand Bernarr
# 19  2025-01-21       Gratitude  Durand Bernarr        DUR&  Durand Bernarr
# 18  2025-01-21          H.I.M.  Durand Bernarr        DUR&  Durand Bernarr
# 17  2025-01-21        Relocate  Durand Bernarr        DUR&  Durand Bernarr
# 16  2025-01-21       Curiosity  Durand Bernarr        DUR&  Durand Bernarr
# 15  2025-01-21         Company  Durand Bernarr        DUR&  Durand Bernarr
# 25  2025-01-21             GPS  Durand Bernarr    En Route  Durand Bernarr
# 12  2025-01-21          MIXXED  Durand Bernarr        DUR&  Durand Bernarr
# 1   2025-01-20      Footprints  Durand Bernarr  Wanderlust  Durand Bernarr
# 11  2025-01-20    Intermission  Durand Bernarr  Wanderlust  Durand Bernarr
# 10  2025-01-20            H.I.  Durand Bernarr  Wanderlust  Durand Bernarr
# 9   2025-01-20         Vacancy  Durand Bernarr  Wanderlust  Durand Bernarr
# 8   2025-01-20    Mango Butter  Durand Bernarr  Wanderlust  Durand Bernarr
# 7   2025-01-20         Rollin’  Durand Bernarr  Wanderlust  Durand Bernarr
# 6   2025-01-20     Destination  Durand Bernarr  Wanderlust  Durand Bernarr
# 5   2025-01-20  New Management  Durand Bernarr  Wanderlust  Durand Bernarr
# 4   2025-01-20     Ingredients  Durand Bernarr  Wanderlust  Durand Bernarr
# 3   2025-01-20         Leveled  Durand Bernarr  Wanderlust  Durand Bernarr
# 2   2025-01-20         Lil Bit  Durand Bernarr  Wanderlust  Durand Bernarr
# 0   2025-01-20      Boundaries  Durand Bernarr  Wanderlust  Durand Bernarr
#
#    lastModifiedDate
# 13       2025-01-21
# 14       2025-01-21
# 24       2025-01-21
# 23       2025-01-21
# 22       2025-01-21
# 21       2025-01-21
# 20       2025-01-21
# 19       2025-01-21
# 18       2025-01-21
# 17       2025-01-21
# 16       2025-01-21
# 15       2025-01-21
# 25       2025-01-21
# 12       2025-01-21
# 1        2025-01-21
# 11       2025-01-21
# 10       2025-01-21
# 9        2025-01-21
# 8        2025-01-21
# 7        2025-01-21
# 6        2025-01-21
# 5        2025-01-21
# 4        2025-01-21
# 3        2025-01-21
# 2        2025-01-21
# 0        2025-01-21

# %%
#Show most recent song added to Tyler the Creator playlist
TTC_play = df[df['playlistName']=='Tyler the Creator']
TTC_play.sort_values(by='addedDate', ascending=False)
# Out:
#       addedDate                                          trackName  \
# 225  2025-02-05                                               OKRA
# 224  2025-02-05                        Pothole (feat. Jaden Smith)
# 223  2025-02-05                     Who Dat Boy (feat. A$AP Rocky)
# 222  2025-01-15                                           THAT GUY
# 212  2025-01-13                    RUNITUP (feat. Teezo Touchdown)
# 221  2025-01-13                      Come On, Let's Go (with Nigo)
# 220  2025-01-13                                    SORRY NOT SORRY
# 219  2025-01-13       BOYFRIEND, GIRLFRIEND (2020 Demo) (feat. YG)
# 218  2025-01-13                                       HEAVEN TO ME
# 217  2025-01-13                                           DOGTOOTH
# 216  2025-01-13                      WHARF TALK (feat. A$AP Rocky)
# 215  2025-01-13                     STUNTMAN (feat. Vince Staples)
# 214  2025-01-13                                           WILSHIRE
# 213  2025-01-13  JUGGERNAUT (feat. Lil Uzi Vert & Pharrell Will...
# 211  2025-01-13                          LEMONHEAD (feat. 42 Dugg)
# 210  2024-11-12                             GONE, GONE / THANK YOU
# 197  2024-10-29                                        Rah Tah Tah
# 209  2024-10-29                      I Hope You Find Your Way Home
# 208  2024-10-29                            Balloon (feat. Doechii)
# 207  2024-10-29                        Like Him (feat. Lola Young)
# 206  2024-10-29  Thought I Was Dead (feat. ScHoolboy Q & Santig...
# 205  2024-10-29                                           Tomorrow
# 204  2024-10-29  Take Your Mask Off (feat. Daniel Caesar & LaTo...
# 203  2024-10-29     Sticky (feat. GloRilla, Sexyy Red & Lil Wayne)
# 202  2024-10-29                                         Judge Judy
# 201  2024-10-29                                       I Killed You
# 200  2024-10-29                                           Hey Jane
# 199  2024-10-29                 Darling, I (feat. Teezo Touchdown)
# 198  2024-10-29                                               Noid
# 196  2024-10-29                   St. Chroma (feat. Daniel Caesar)
#
#              artistName                                     album  \
# 225  Tyler, The Creator                                      OKRA
# 224  Tyler, The Creator                                Flower Boy
# 223  Tyler, The Creator                                Flower Boy
# 222               etmnx                                  THAT GUY
# 212  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 221  Tyler, The Creator                              I Know NIGO!
# 220  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 219  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 218  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 217  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 216  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 215  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 214  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 213  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 211  Tyler, The Creator  CALL ME IF YOU GET LOST: The Estate Sale
# 210  Tyler, The Creator                                      IGOR
# 197  Tyler, The Creator                               CHROMAKOPIA
# 209  Tyler, The Creator                               CHROMAKOPIA
# 208  Tyler, The Creator                               CHROMAKOPIA
# 207  Tyler, The Creator                               CHROMAKOPIA
# 206  Tyler, The Creator                               CHROMAKOPIA
# 205  Tyler, The Creator                               CHROMAKOPIA
# 204  Tyler, The Creator                               CHROMAKOPIA
# 203  Tyler, The Creator                               CHROMAKOPIA
# 202  Tyler, The Creator                               CHROMAKOPIA
# 201  Tyler, The Creator                               CHROMAKOPIA
# 200  Tyler, The Creator                               CHROMAKOPIA
# 199  Tyler, The Creator                               CHROMAKOPIA
# 198  Tyler, The Creator                               CHROMAKOPIA
# 196  Tyler, The Creator                               CHROMAKOPIA
#
#           playlistName lastModifiedDate
# 225  Tyler the Creator       2025-02-05
# 224  Tyler the Creator       2025-02-05
# 223  Tyler the Creator       2025-02-05
# 222  Tyler the Creator       2025-02-05
# 212  Tyler the Creator       2025-02-05
# 221  Tyler the Creator       2025-02-05
# 220  Tyler the Creator       2025-02-05
# 219  Tyler the Creator       2025-02-05
# 218  Tyler the Creator       2025-02-05
# 217  Tyler the Creator       2025-02-05
# 216  Tyler the Creator       2025-02-05
# 215  Tyler the Creator       2025-02-05
# 214  Tyler the Creator       2025-02-05
# 213  Tyler the Creator       2025-02-05
# 211  Tyler the Creator       2025-02-05
# 210  Tyler the Creator       2025-02-05
# 197  Tyler the Creator       2025-02-05
# 209  Tyler the Creator       2025-02-05
# 208  Tyler the Creator       2025-02-05
# 207  Tyler the Creator       2025-02-05
# 206  Tyler the Creator       2025-02-05
# 205  Tyler the Creator       2025-02-05
# 204  Tyler the Creator       2025-02-05
# 203  Tyler the Creator       2025-02-05
# 202  Tyler the Creator       2025-02-05
# 201  Tyler the Creator       2025-02-05
# 200  Tyler the Creator       2025-02-05
# 199  Tyler the Creator       2025-02-05
# 198  Tyler the Creator       2025-02-05
# 196  Tyler the Creator       2025-02-05

# %%
#Creat separate dataframe of new songs that were added to playlists after download
new_songs = {'addedDate': ['NaN','NaN','NaN','NaN','NaN','NaN','NaN','NaN',
                          'NaN','NaN','NaN','NaN','NaN','NaN','NaN','NaN',
                          'NaN','NaN','NaN','NaN','NaN','NaN','NaN','NaN'],
            'trackName':['GENEROUS','Flounce','Impact','Jump','No Business','Overqualified','Unspoken','Completed','Reaching','PSST!','Here We Are','BLAST!','THAT!','Specialty','Home Alone',
                        'Must Be Nice','Unknown','Fist Bump (feat. Free Nationals)','PIT STOP','Neutral','Processing...','ETA?',
                        'AUCTION','Taste'],
            'artistName':['Durand Bernarr','Durand Bernarr, GAWD','Durand Bernarr','Durand Bernarr','Durand Bernarr, E-WHIZZ','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr, T-Pain','Durand Bernarr','Durand Bernarr',
                         'Durand Bernarr','Durand Bernarr','Durand Bernarr, Free Nationals','Durand Bernarr, DeShawn Jenkins','Durand Bernarr','Durand Bernarr','Durand Bernarr',
                         'Sasha Keable, DESTIN CONRAD','Coco Jones'],
            'album' :['BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM','BLOOM',
                     'En Route','En Route','En Route','En Route','En Route','En Route','En Route',
                     'AUCTION','Taste'],
            'playlistName' :['Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr',
                         'Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr','Durand Bernarr',
                            'Favorites','Favorites'],
            'lastModifiedDate':['NaN','NaN','NaN','NaN','NaN','NaN','NaN','NaN',
                               'NaN','NaN','NaN','NaN','NaN','NaN','NaN','NaN',
                               'NaN','NaN','NaN','NaN','NaN','NaN','NaN','NaN']}
new_songs_df = pd.DataFrame(new_songs)
new_songs_df
# Out:
#    addedDate                         trackName  \
# 0        NaN                          GENEROUS
# 1        NaN                           Flounce
# 2        NaN                            Impact
# 3        NaN                              Jump
# 4        NaN                       No Business
# 5        NaN                     Overqualified
# 6        NaN                          Unspoken
# 7        NaN                         Completed
# 8        NaN                          Reaching
# 9        NaN                             PSST!
# 10       NaN                       Here We Are
# 11       NaN                            BLAST!
# 12       NaN                             THAT!
# 13       NaN                         Specialty
# 14       NaN                        Home Alone
# 15       NaN                      Must Be Nice
# 16       NaN                           Unknown
# 17       NaN  Fist Bump (feat. Free Nationals)
# 18       NaN                          PIT STOP
# 19       NaN                           Neutral
# 20       NaN                     Processing...
# 21       NaN                              ETA?
# 22       NaN                           AUCTION
# 23       NaN                             Taste
#
#                          artistName     album    playlistName lastModifiedDate
# 0                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 1              Durand Bernarr, GAWD     BLOOM  Durand Bernarr              NaN
# 2                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 3                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 4           Durand Bernarr, E-WHIZZ     BLOOM  Durand Bernarr              NaN
# 5                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 6                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 7                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 8                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 9                    Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 10                   Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 11                   Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 12           Durand Bernarr, T-Pain     BLOOM  Durand Bernarr              NaN
# 13                   Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 14                   Durand Bernarr     BLOOM  Durand Bernarr              NaN
# 15                   Durand Bernarr  En Route  Durand Bernarr              NaN
# 16                   Durand Bernarr  En Route  Durand Bernarr              NaN
# 17   Durand Bernarr, Free Nationals  En Route  Durand Bernarr              NaN
# 18  Durand Bernarr, DeShawn Jenkins  En Route  Durand Bernarr              NaN
# 19                   Durand Bernarr  En Route  Durand Bernarr              NaN
# 20                   Durand Bernarr  En Route  Durand Bernarr              NaN
# 21                   Durand Bernarr  En Route  Durand Bernarr              NaN
# 22      Sasha Keable, DESTIN CONRAD   AUCTION       Favorites              NaN
# 23                       Coco Jones     Taste       Favorites              NaN

# %%
#Combine dataframes for final result
df=pd.concat([df, new_songs_df], ignore_index=True)
df
# Out:
#        addedDate      trackName                   artistName       album  \
# 0     2025-01-20     Boundaries               Durand Bernarr  Wanderlust
# 1     2025-01-20     Footprints               Durand Bernarr  Wanderlust
# 2     2025-01-20        Lil Bit               Durand Bernarr  Wanderlust
# 3     2025-01-20        Leveled               Durand Bernarr  Wanderlust
# 4     2025-01-20    Ingredients               Durand Bernarr  Wanderlust
# ...          ...            ...                          ...         ...
# 2445         NaN        Neutral               Durand Bernarr    En Route
# 2446         NaN  Processing...               Durand Bernarr    En Route
# 2447         NaN           ETA?               Durand Bernarr    En Route
# 2448         NaN        AUCTION  Sasha Keable, DESTIN CONRAD     AUCTION
# 2449         NaN          Taste                   Coco Jones       Taste
#
#         playlistName lastModifiedDate
# 0     Durand Bernarr       2025-01-21
# 1     Durand Bernarr       2025-01-21
# 2     Durand Bernarr       2025-01-21
# 3     Durand Bernarr       2025-01-21
# 4     Durand Bernarr       2025-01-21
# ...              ...              ...
# 2445  Durand Bernarr              NaN
# 2446  Durand Bernarr              NaN
# 2447  Durand Bernarr              NaN
# 2448       Favorites              NaN
# 2449       Favorites              NaN
#
# [2450 rows x 6 columns]

# %% [markdown]
# ### Final Result
#
# The final result is a single indexed dataframe that contains all the songs in all of my playlists. For the new songs that I added I didn't put anything for the addedDate and lastModifiedDate columns because this is information that I'll have when I download this data again from Spotify next year.
